# %%
import pymongo
import pandas as pd

# %%
import certifi
ca = certifi.where()
client = pymongo.MongoClient(
"mongodb+srv://saravanan:San123456@cluster0.z7u66ej.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0", tlsCAFile=ca)
db = client['sample_airbnb']
collection = db['listingsAndReviews']

# %%
data_list = []
for data in collection.find({},{"_id": 0}):
  data_list.append(data)

df = pd.DataFrame(data_list)

# %%
pd.set_option("display.max_column", None)

# %%
df.head()
# Out:
#                              listing_url                                name  \
# 0  https://www.airbnb.com/rooms/10047964      Charming Flat in Downtown Moda
# 1  https://www.airbnb.com/rooms/10059872  Soho Cozy, Spacious and Convenient
# 2  https://www.airbnb.com/rooms/10057826                   Deluxe Loft Suite
# 3  https://www.airbnb.com/rooms/10066928      3 chambres au coeur du Plateau
# 4  https://www.airbnb.com/rooms/10215858            Cozy Queen Guest Room&My
#
#                                              summary  \
# 0  Fully furnished 3+1 flat decorated with vintag...
# 1  Clean, fully furnish, Spacious 1 bedroom flat ...
# 2  Loft Suite Deluxe @ Henry Norman Hotel Located...
# 3  Notre appartement comporte 3 chambres avec cha...
# 4  Mong Kok MTR E1 walk 100 meters, shopping, eat...
#
#                                                space  \
# 0  The apartment is composed of 1 big bedroom wit...
# 1
# 2  This loft unit features a kitchenette and is f...
# 3  Notre logement est lumineux, plein de vie et c...
# 4  The double bed is good for 2 people.  Also has...
#
#                                          description  \
# 0  Fully furnished 3+1 flat decorated with vintag...
# 1  Clean, fully furnish, Spacious 1 bedroom flat ...
# 2  Loft Suite Deluxe @ Henry Norman Hotel Located...
# 3  Notre appartement comporte 3 chambres avec cha...
# 4  Mong Kok MTR E1 walk 100 meters, shopping, eat...
#
#                                neighborhood_overview  \
# 0  With its diversity Moda- Kadikoy is one of the...
# 1
# 2  Greenpoint is an artsy Brooklyn neighborhood f...
# 3  L'appartement se situe au coeur du Plateau, do...
# 4  Electric Street, Mong Kok near there (Sai Yeun...
#
#                                                notes  \
# 0
# 1
# 2
# 3
# 4  After check-in time is 14:00, check out time i...
#
#                                              transit  \
# 0
# 1
# 2
# 3  L'appartement se situe à égale distance des mé...
# 4  ❤ walk from my house to go up within 5-15 minu...
#
#                                               access  \
# 0
# 1
# 2  Guest will have access to common terraces, lou...
# 3  Le logement sera disponible en entier pour vot...
# 4  Each guest room is equipped with free access t...
#
#                                          interaction  \
# 0
# 1
# 2
# 3  N'hésitez pas à m'écrire pour toute demande de...
# 4  We have someone in charge of the reception eve...
#
#                                          house_rules property_type  \
# 0  Be and feel like your own home, with total res...         House
# 1                                                        Apartment
# 2  Guest must leave a copy of credit card with fr...     Apartment
# 3                 Merci de respecter ce lieu de vie.     Apartment
# 4  No smoking, let us all have a good air environ...     Apartment
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0  Entire home/apt  Real Bed              2           1125
# 1  Entire home/apt  Real Bed              4             20
# 2  Entire home/apt  Real Bed              3           1125
# 3  Entire home/apt  Real Bed              1           1125
# 4     Private room  Real Bed              1            500
#
#            cancellation_policy        last_scraped calendar_last_scraped  \
# 0                     flexible 2019-02-18 05:00:00   2019-02-18 05:00:00
# 1                     flexible 2019-03-11 04:00:00   2019-03-11 04:00:00
# 2  strict_14_with_grace_period 2019-03-07 05:00:00   2019-03-07 05:00:00
# 3                     flexible 2019-03-11 04:00:00   2019-03-11 04:00:00
# 4  strict_14_with_grace_period 2019-03-11 04:00:00   2019-03-11 04:00:00
#
#          first_review         last_review  accommodates  bedrooms  beds  \
# 0 2016-04-02 04:00:00 2016-04-02 04:00:00             6       2.0   6.0
# 1 2015-12-19 05:00:00 2018-03-27 04:00:00             3       1.0   2.0
# 2 2016-01-03 05:00:00 2018-02-18 05:00:00             4       0.0   2.0
# 3                 NaT                 NaT             6       3.0   3.0
# 4 2016-07-13 04:00:00 2018-11-06 05:00:00             2       1.0   1.0
#
#    number_of_reviews bathrooms  \
# 0                  1       1.0
# 1                  3       1.0
# 2                  5       1.0
# 3                  0       1.0
# 4                  9       1.0
#
#                                            amenities   price cleaning_fee  \
# 0  [TV, Cable TV, Internet, Wifi, Kitchen, Free p...  527.00       211.00
# 1  [Air conditioning, Kitchen, Smoking allowed, D...  699.00          NaN
# 2  [TV, Cable TV, Internet, Wifi, Air conditionin...  205.00          NaN
# 3  [Internet, Wifi, Kitchen, Heating, Family/kid ...  140.00          NaN
# 4  [TV, Wifi, Air conditioning, Doorman, Elevator...  330.00          NaN
#
#   extra_people guests_included  \
# 0       211.00               1
# 1         0.00               1
# 2         0.00               1
# 3         0.00               1
# 4         0.00               1
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '1241644', 'host_url': 'https://ww...
# 1  {'host_id': '51624384', 'host_url': 'https://w...
# 2  {'host_id': '47554473', 'host_url': 'https://w...
# 3  {'host_id': '9036477', 'host_url': 'https://ww...
# 4  {'host_id': '52473150', 'host_url': 'https://w...
#
#                                              address  \
# 0  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 1  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 2  {'street': 'Brooklyn, NY, United States', 'sub...
# 3  {'street': 'Montréal, Québec, Canada', 'suburb...
# 4  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
#
#                                         availability  \
# 0  {'availability_30': 27, 'availability_60': 57,...
# 1  {'availability_30': 0, 'availability_60': 0, '...
# 2  {'availability_30': 30, 'availability_60': 31,...
# 3  {'availability_30': 0, 'availability_60': 0, '...
# 4  {'availability_30': 20, 'availability_60': 50,...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
# 1  {'review_scores_accuracy': 10, 'review_scores_...
# 2  {'review_scores_accuracy': 9, 'review_scores_c...
# 3                                                 {}
# 4  {'review_scores_accuracy': 8, 'review_scores_c...
#
#                                              reviews weekly_price  \
# 0  [{'_id': '68162172', 'date': 2016-04-02 04:00:...          NaN
# 1  [{'_id': '56904633', 'date': 2015-12-19 05:00:...      5000.00
# 2  [{'_id': '58665374', 'date': 2016-01-03 05:00:...          NaN
# 3                                                 []          NaN
# 4  [{'_id': '85819981', 'date': 2016-07-13 04:00:...          NaN
#
#   security_deposit monthly_price  reviews_per_month
# 0              NaN           NaN                NaN
# 1              NaN           NaN                NaN
# 2              NaN           NaN                NaN
# 3              NaN           NaN                NaN
# 4              NaN           NaN                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_url            5555 non-null   object
#  1   name                   5555 non-null   object
#  2   summary                5555 non-null   object
#  3   space                  5555 non-null   object
#  4   description            5555 non-null   object
#  5   neighborhood_overview  5555 non-null   object
#  6   notes                  5555 non-null   object
#  7   transit                5555 non-null   object
#  8   access                 5555 non-null   object
#  9   interaction            5555 non-null   object
#  10  house_rules            5555 non-null   object
#  11  property_type          5555 non-null   object
#  12  room_type              5555 non-null   object
#  13  bed_type               5555 non-null   object
#  14  minimum_nights         5555 non-null   object
#  15  maximum_nights         5555 non-null   object
#  16  cancellation_policy    5555 non-null   object
#  17  last_scraped           5555 non-null   datetime64[ns]
#  18  calendar_last_scraped  5555 non-null   datetime64[ns]
#  19  first_review           4167 non-null   datetime64[ns]
#  20  last_review            4167 non-null   datetime64[ns]
#  21  accommodates           5555 non-null   int64
#  22  bedrooms               5550 non-null   float64
#  23  beds                   5542 non-null   float64
#  24  number_of_reviews      5555 non-null   int64
#  25  bathrooms              5545 non-null   object
#  26  amenities              5555 non-null   object
#  27  price                  5555 non-null   object
#  28  cleaning_fee           4024 non-null   object
#  29  extra_people           5555 non-null   object
#  30  guests_included        5555 non-null   object
#  31  images                 5555 non-null   object
#  32  host                   5555 non-null   object
#  33  address                5555 non-null   object
#  34  availability           5555 non-null   object
#  35  review_scores          5555 non-null   object
#  36  reviews                5555 non-null   object
#  37  weekly_price           714 non-null    object
#  38  security_deposit       3471 non-null   object
#  39  monthly_price          656 non-null    object
#  40  reviews_per_month      94 non-null     float64
# dtypes: datetime64[ns](4), float64(3), int64(2), object(32)
# memory usage: 1.7+ MB

# %%
df['last_scraped'] = pd.to_datetime(df['last_scraped'])
df['calendar_last_scraped'] = pd.to_datetime(df['calendar_last_scraped'])
df['first_review'] = pd.to_datetime(df['first_review'])
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df['minimum_nights'] = pd.to_numeric(df['minimum_nights'])
df['maximum_nights'] = pd.to_numeric(df['maximum_nights'])
df['bathrooms'] = pd.to_numeric(df['bathrooms'], errors='coerce')

# %%
df['amenities'] = df['amenities'].apply(lambda x: ', '.join(x))

# %%
for i in df.columns:
  print(i, " : ", df[i].duplicated().sum())
# Out:
# listing_url  :  0
# name  :  17
# summary  :  295
# space  :  1667
# description  :  113
# neighborhood_overview  :  2327
# notes  :  3173
# transit  :  2324
# access  :  2566
# interaction  :  2638
# house_rules  :  2442
# property_type  :  5519
# room_type  :  5552
# bed_type  :  5550
# minimum_nights  :  5510
# maximum_nights  :  5415
# cancellation_policy  :  5550
# last_scraped  :  5548
# calendar_last_scraped  :  5548
# first_review  :  3868
# last_review  :  4745
# accommodates  :  5539
# bedrooms  :  5541
# beds  :  5535
# number_of_reviews  :  5296
# bathrooms  :  5554
# amenities  :  86
# price  :  4906
# cleaning_fee  :  5263
# extra_people  :  5417
# guests_included  :  5541
# images  :  2
# host  :  451
# address  :  0
# availability  :  2684
# review_scores  :  4391
# reviews  :  1631
# weekly_price  :  5231
# security_deposit  :  5341
# monthly_price  :  5245
# reviews_per_month  :  5546

# %%
df = df.astype(str)
duplicates_count = df.duplicated().sum()
print("Number of duplicated rows:", duplicates_count)
# Out:
# Number of duplicated rows: 0
